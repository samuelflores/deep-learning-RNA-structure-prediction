# %%
import os
from pathlib import Path
import sys
import shutil
import json

# %%
def move_eval_json_up(dir_path):
    eval_results_dir = os.listdir(dir_path/"results")[0]
    eval_results_path = dir_path/"results"/eval_results_dir/"eval_results.json"
    shutil.move(eval_results_path, dir_path/"eval_results.json")

# %%
def format_model_folder(PATH):

    # list checkpoints
    checkpoints = os.listdir(PATH)
    if "eval_results.json" in checkpoints: checkpoints.remove("eval_results.json")
    if "results" in checkpoints: checkpoints.remove("results")
    if "runs" in checkpoints: checkpoints.remove("runs")
    checkpoints.sort(key=lambda x: int(x.split("-")[-1]))
    latest_dir = checkpoints[-1]

    # get trainer state
    trainer_state_path = PATH/latest_dir/"trainer_state.json"
    with open(trainer_state_path, "r") as file:
        trainer_state = json.load(file)

    # move trainer state up
    shutil.move(trainer_state_path, PATH/"trainer_state.json")

    best_dir = Path(trainer_state['best_model_checkpoint']).parts[-1]

    # Remove non-best models
    checkpoints.remove(best_dir)
    for dir in checkpoints:
        shutil.rmtree(PATH/dir)

    # move contents of best model up
    for file in os.listdir(PATH/best_dir):
        if file == "trainer_state.json":
            os.remove(PATH/best_dir/file)
        else:
            shutil.move(PATH/best_dir/file, PATH/file)

    # remove empty folder
    shutil.rmtree(PATH/best_dir)

# %%
def clean_up(path):
    # Move eval_results.json up
    move_eval_json_up(path)

    # Delete empty "results" folder
    shutil.rmtree(path/"results")
    shutil.rmtree(path/"runs")
    
    # save trainer_state.json from latest checkpoint, but model from best checkpoint
    format_model_folder(path)

# %%
# #! ONLY RUN THIS FOR FRESH DNABERT2 RUNS
ROOT_DIR = Path("results/DNABERT2/alvis/tetraloop/homology_reduced")

for dir in os.listdir(ROOT_DIR):
    if not os.path.exists(ROOT_DIR/dir/"eval_results.json"):
        if os.path.exists(ROOT_DIR/dir/"results"):
            clean_up(ROOT_DIR/dir)
            # pass
        # else:
        #     shutil.rmtree(ROOT_DIR/dir)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [5], line 7
#       5 if not os.path.exists(ROOT_DIR/dir/"eval_results.json"):
#       6     if os.path.exists(ROOT_DIR/dir/"results"):
# ----> 7         clean_up(ROOT_DIR/dir)
#
# Cell In [4], line 10, in clean_up(path)
#       7 shutil.rmtree(path/"runs")
#       9 # save trainer_state.json from latest checkpoint, but model from best checkpoint
# ---> 10 format_model_folder(path)
#
# Cell In [3], line 9, in format_model_folder(PATH)
#       7 if "runs" in checkpoints: checkpoints.remove("runs")
#       8 checkpoints.sort(key=lambda x: int(x.split("-")[-1]))
# ----> 9 latest_dir = checkpoints[-1]
#      11 # get trainer state
#      12 trainer_state_path = PATH/latest_dir/"trainer_state.json"
#
# IndexError: list index out of range

# %%
# clean_up(Path("results/DNABERT2/alvis/tetraloop/"))

# %%
# PATH = Path("results/DNABERT2/alvis/tetraloop")

# for dir in os.listdir(PATH):
#     if dir.split("_")[0] == "gnra":
#         old_name = PATH/dir
#         print(old_name)

#         new_name = dir.split("_")[1:]
#         new_name.insert(0,"gnravall")
#         new_name = "_".join(new_name)
#         new_name = PATH/new_name
#         print(new_name)
        
#         os.rename(old_name, new_name)
# Out:
# results/DNABERT2/alvis/tetraloop/gnra_12_80_T_10
# results/DNABERT2/alvis/tetraloop/gnravall_12_80